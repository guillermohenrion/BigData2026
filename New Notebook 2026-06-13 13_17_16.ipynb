# %%
# Curso básico de Python

# 1. Variables y tipos de datos
nombre = "Juan"
edad = 25
altura = 1.75
es_estudiante = True

# 2. Operaciones básicas
suma = 5 + 3
resta = 10 - 2
multiplicacion = 4 * 6
division = 8 / 2

# 3. Estructuras de control
if edad > 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")

# 4. Bucles
for i in range(5):
    print("Número:", i)

# 5. Funciones
def saludar(nombre):
    print(f"Hola, {nombre}!")

saludar("Ana")

# 6. Listas y diccionarios
frutas = ["manzana", "banana", "naranja"]
for fruta in frutas:
    print(fruta)

persona = {"nombre": "Carlos", "edad": 30}
print(persona["nombre"])

# 7. Uso de Spark DataFrame en Databricks
data = [("Juan", 25), ("Ana", 22), ("Luis", 28)]
columns = ["Nombre", "Edad"]
df = spark.createDataFrame(data, columns)
display(df)
